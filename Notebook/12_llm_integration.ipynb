# %%
import os
import sys
import numpy as np
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from LLM.prompt_builder import PromptBuilder
from LLM.llm_model import EmotionLLM

# %%
builder = PromptBuilder()

embedding = np.random.rand(128)

prompt = builder.build_prompt(
    emotion="happy",
    confidence=98.42,
    embedding=embedding
)

# %%
llm = EmotionLLM()
# Out:
# Loading Tokenizer...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading Model...
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# LLM Loaded Successfully

# %%
response = llm.generate(
    prompt,
    max_tokens=80
)

print(response)
# Out:
# You are not running the flash-attention implementation, expect numerical differences.
# It's wonderful to hear you're feeling happy! Remember, it's okay to take a moment for yourself to celebrate your achievements. Enjoy this feeling and let it motivate you to keep striving for your goals.
